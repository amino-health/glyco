# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
gl= pd.read_csv('../data/glucose_mean_paisen2.csv', sep=';', skiprows=1)

# %%
igl=gl.set_index(['CLASS'])

# %%
igl['AVERAGE'].replace(',','.')
# Out:
# CLASS
# 1    149,96
# 1    154,28
# 3    323,39
# 2    255,45
# 1    179,09
# 2    237,53
# 1    192,56
# 1    195,36
# 2    212,84
# 1    175,97
# 2    220,37
# 2    234,88
# 1    189,32
# 2    218,54
# 2    206,12
# 3    422,84
# 2    234,03
# 1    175,42
# 2    271,96
# 2    250,17
# 2    249,22
# 2    220,57
# 3    431,16
# 2    206,12
# 1    176,24
# 1    170,28
# 2    250,95
# 1    153,10
# 2    282,59
# 1    151,46
# 1    141,41
# 1    179,41
# 2    256,12
# 1    151,41
# 1    197,88
# 1    166,33
# 3    402,18
# 2    232,22
# 2    228,02
# 1    175,97
# 3    308,87
# 2    282,59
# Name: AVERAGE, dtype: object

# %%
igl['av']=igl['AVERAGE'].str.replace(',','.').astype(float)

# %%
igl['st']=igl['STDEVPA'].str.replace(',','.').astype(float)

# %%
# Out:
# <AxesSubplot:xlabel='CLASS'>

# %%
igl.STDEVPA

# %%
import seaborn as sns

# %%
sns.boxplot(igl.index, igl.av)
# Out:
# /Users/ismail/precision/repos/glyco/venv/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CLASS', ylabel='av'>

# %%
sns.boxplot(igl.index, igl.st)
# Out:
# /Users/ismail/precision/repos/glyco/venv/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CLASS', ylabel='st'>

# %%
igl.index
# Out:
# Int64Index([1, 1, 3, 2, 1, 2, 1, 1, 2, 1, 2, 2, 1, 2, 2, 3, 2, 1, 2, 2, 2, 2,
#             3, 2, 1, 1, 2, 1, 2, 1, 1, 1, 2, 1, 1, 1, 3, 2, 2, 1, 3, 2],
#            dtype='int64', name='CLASS')
