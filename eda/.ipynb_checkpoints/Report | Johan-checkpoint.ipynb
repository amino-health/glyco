# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt
import os
from os.path import isfile, join, getctime
import seaborn as sns
from matplotlib import pyplot as plt

# %%
PATH_MEAL_PHOTOS= '../data/photos_johan/'
PATH_GLUCOSE='../data/johan_glucose.csv'

# %%
def end_plot():
    plt.xticks(rotation=45)
    plt.legend()
    plt.show()

def resize(l=8, w=6):
    plt.figure(num=None, figsize=(l, w), dpi=120, facecolor='w', edgecolor='k')
from datetime import timedelta as tdel
def shift_fwd(t, h=1, m=0):
    return t+ tdel(hours=h, minutes=m)
def shift_back(t, h=1, m=0):
    return t- tdel(hours=h, minutes=m)

# %%
def normalize(ser):
    return (ser - ser.mean()) / ser.std()

# %% [markdown]
# ## Shift time by one hour first

# %%
def get_meals(photos_path, shift=True):
    if not(shift):
        raise Exception('NOT SHIFTING TIME?')
    files_ts = [
        # shift by one hour
    (shift_back(dt.fromtimestamp(os.stat(photos_path+f).st_mtime)), f) 
    for f in os.listdir(photos_path) if isfile(join(photos_path, f))]
    fs = [(f[0].day, f[0].hour, f[0].minute, f[0].hour*100+f[0].minute, "{}:{}".format(f[0].hour, f[0].minute), f[0], f[0], f[0].date(), f[1]) for f in files_ts]
    return pd.DataFrame(fs, columns=['day', 'hour', 'minute', 'time_fmt','time_str', 'idx','ctime', 'cdate', 'filename'])

def get_indexed_meals(photos_path, idx):
    df = get_meals(photos_path)
    return df.set_index([idx])

# %%
meals = get_indexed_meals(PATH_MEAL_PHOTOS, 'idx')
meals
# Out:
#                      day  hour  minute  time_fmt time_str               ctime  \
# idx
# 2020-10-03 14:50:36    3    14      50      1450    14:50 2020-10-03 14:50:36
# 2020-10-03 21:05:18    3    21       5      2105     21:5 2020-10-03 21:05:18
# 2020-10-04 07:47:14    4     7      47       747     7:47 2020-10-04 07:47:14
# 2020-10-04 13:04:58    4    13       4      1304     13:4 2020-10-04 13:04:58
# 2020-10-04 14:45:54    4    14      45      1445    14:45 2020-10-04 14:45:54
# 2020-10-04 18:56:54    4    18      56      1856    18:56 2020-10-04 18:56:54
# 2020-10-05 10:14:56    5    10      14      1014    10:14 2020-10-05 10:14:56
# 2020-10-05 17:06:26    5    17       6      1706     17:6 2020-10-05 17:06:26
# 2020-10-05 17:49:58    5    17      49      1749    17:49 2020-10-05 17:49:58
# 2020-10-05 19:51:54    5    19      51      1951    19:51 2020-10-05 19:51:54
# 2020-10-05 20:19:44    5    20      19      2019    20:19 2020-10-05 20:19:44
# 2020-10-05 20:20:10    5    20      20      2020    20:20 2020-10-05 20:20:10
# 2020-10-07 18:04:50    7    18       4      1804     18:4 2020-10-07 18:04:50
# 2020-10-08 05:57:48    8     5      57       557     5:57 2020-10-08 05:57:48
# 2020-10-08 10:52:06    8    10      52      1052    10:52 2020-10-08 10:52:06
# 2020-10-08 11:21:54    8    11      21      1121    11:21 2020-10-08 11:21:54
# 2020-10-08 14:53:16    8    14      53      1453    14:53 2020-10-08 14:53:16
# 2020-10-08 19:00:34    8    19       0      1900     19:0 2020-10-08 19:00:34
# 2020-10-08 19:14:22    8    19      14      1914    19:14 2020-10-08 19:14:22
# 2020-10-09 13:45:28    9    13      45      1345    13:45 2020-10-09 13:45:28
# 2020-10-10 08:59:04   10     8      59       859     8:59 2020-10-10 08:59:04
# 2020-10-10 12:15:06   10    12      15      1215    12:15 2020-10-10 12:15:06
# 2020-10-10 14:20:52   10    14      20      1420    14:20 2020-10-10 14:20:52
# 2020-10-10 19:34:22   10    19      34      1934    19:34 2020-10-10 19:34:22
# 2020-10-11 07:17:54   11     7      17       717     7:17 2020-10-11 07:17:54
# 2020-10-11 07:18:00   11     7      18       718     7:18 2020-10-11 07:18:00
# 2020-10-11 12:34:14   11    12      34      1234    12:34 2020-10-11 12:34:14
# 2020-10-11 15:06:00   11    15       6      1506     15:6 2020-10-11 15:06:00
# 2020-10-11 18:01:02   11    18       1      1801     18:1 2020-10-11 18:01:02
# 2020-10-12 10:14:34   12    10      14      1014    10:14 2020-10-12 10:14:34
# 2020-10-12 10:43:30   12    10      43      1043    10:43 2020-10-12 10:43:30
# 2020-10-12 14:25:04   12    14      25      1425    14:25 2020-10-12 14:25:04
# 2020-10-12 15:22:30   12    15      22      1522    15:22 2020-10-12 15:22:30
# 2020-10-12 18:43:28   12    18      43      1843    18:43 2020-10-12 18:43:28
# 2020-10-14 08:26:40   14     8      26       826     8:26 2020-10-14 08:26:40
# 2020-10-14 10:20:16   14    10      20      1020    10:20 2020-10-14 10:20:16
# 2020-10-14 14:57:08   14    14      57      1457    14:57 2020-10-14 14:57:08
# 2020-10-15 16:41:20   15    16      41      1641    16:41 2020-10-15 16:41:20
# 2020-10-16 10:23:46   16    10      23      1023    10:23 2020-10-16 10:23:46
# 2020-10-16 14:25:04   16    14      25      1425    14:25 2020-10-16 14:25:04
# 2020-10-16 18:42:26   16    18      42      1842    18:42 2020-10-16 18:42:26
# 2020-10-16 19:49:56   16    19      49      1949    19:49 2020-10-16 19:49:56
#
#                           cdate      filename
# idx
# 2020-10-03 14:50:36  2020-10-03  IMG_0387.jpg
# 2020-10-03 21:05:18  2020-10-03  IMG_0389.jpg
# 2020-10-04 07:47:14  2020-10-04  IMG_0390.jpg
# 2020-10-04 13:04:58  2020-10-04  IMG_0391.jpg
# 2020-10-04 14:45:54  2020-10-04  IMG_0392.jpg
# 2020-10-04 18:56:54  2020-10-04  IMG_0396.jpg
# 2020-10-05 10:14:56  2020-10-05  IMG_0401.jpg
# 2020-10-05 17:06:26  2020-10-05  IMG_0404.jpg
# 2020-10-05 17:49:58  2020-10-05  IMG_0406.jpg
# 2020-10-05 19:51:54  2020-10-05  IMG_0409.jpg
# 2020-10-05 20:19:44  2020-10-05  IMG_0412.jpg
# 2020-10-05 20:20:10  2020-10-05  IMG_0413.jpg
# 2020-10-07 18:04:50  2020-10-07  IMG_0426.jpg
# 2020-10-08 05:57:48  2020-10-08  IMG_0427.jpg
# 2020-10-08 10:52:06  2020-10-08  IMG_0430.jpg
# 2020-10-08 11:21:54  2020-10-08  IMG_0431.jpg
# 2020-10-08 14:53:16  2020-10-08  IMG_0432.jpg
# 2020-10-08 19:00:34  2020-10-08  IMG_0434.jpg
# 2020-10-08 19:14:22  2020-10-08  IMG_0435.jpg
# 2020-10-09 13:45:28  2020-10-09  IMG_0441.jpg
# 2020-10-10 08:59:04  2020-10-10  IMG_0446.jpg
# 2020-10-10 12:15:06  2020-10-10  IMG_0451.jpg
# 2020-10-10 14:20:52  2020-10-10  IMG_0460.jpg
# 2020-10-10 19:34:22  2020-10-10  IMG_0462.jpg
# 2020-10-11 07:17:54  2020-10-11  IMG_0468.jpg
# 2020-10-11 07:18:00  2020-10-11  IMG_0469.jpg
# 2020-10-11 12:34:14  2020-10-11  IMG_0473.jpg
# 2020-10-11 15:06:00  2020-10-11  IMG_0476.jpg
# 2020-10-11 18:01:02  2020-10-11  IMG_0477.jpg
# 2020-10-12 10:14:34  2020-10-12  IMG_0486.jpg
# 2020-10-12 10:43:30  2020-10-12  IMG_0487.jpg
# 2020-10-12 14:25:04  2020-10-12  IMG_0488.jpg
# 2020-10-12 15:22:30  2020-10-12  IMG_0489.jpg
# 2020-10-12 18:43:28  2020-10-12  IMG_0490.jpg
# 2020-10-14 08:26:40  2020-10-14  IMG_0499.jpg
# 2020-10-14 10:20:16  2020-10-14  IMG_0501.jpg
# 2020-10-14 14:57:08  2020-10-14  IMG_0502.jpg
# 2020-10-15 16:41:20  2020-10-15  IMG_0511.jpg
# 2020-10-16 10:23:46  2020-10-16  IMG_0513.jpg
# 2020-10-16 14:25:04  2020-10-16  IMG_0514.jpg
# 2020-10-16 18:42:26  2020-10-16  IMG_0515.jpg
# 2020-10-16 19:49:56  2020-10-16  IMG_0518.jpg

# %% [markdown]
# # Show meal time distribution

# %%
m_gday = meals.groupby('cdate')

# %%
sns.boxplot(meals.cdate, meals.hour*60+meals.minute)
end_plot()
# Out:
# /Users/ismail/RestInGit/glyco/venv/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# No handles with labels found to put in legend.

# %%
plt.plot(meals.cdate, meals.hour*60+meals.minute, linestyle='none', marker='.')
end_plot()
# Out:
# No handles with labels found to put in legend.

# %%
#def get_daily_meals(mdf):
gday =meals.groupby('cdate')

dateless = lambda x: x.hour*60+x.minute

# %%
mgdf = gday.count()
mgdf['cnt']= mgdf.ctime
mgdf['firstm']=gday['ctime'].min()
mgdf['lastm']=gday['ctime'].max()
mgdf['ftol']=(mgdf['lastm']-mgdf['firstm']).astype('timedelta64[h]')
mgdf['ftol']
# Out:
# cdate
# 2020-10-03     6.0
# 2020-10-04    11.0
# 2020-10-05    10.0
# 2020-10-07     0.0
# 2020-10-08    13.0
# 2020-10-09     0.0
# 2020-10-10    10.0
# 2020-10-11    10.0
# 2020-10-12     8.0
# 2020-10-14     6.0
# 2020-10-15     0.0
# 2020-10-16     9.0
# Name: ftol, dtype: float64

# %%
mgdf
# Out:
#             day  hour  minute  time_fmt  time_str  ctime  filename  cnt  \
# cdate
# 2020-10-03    2     2       2         2         2      2         2    2
# 2020-10-04    4     4       4         4         4      4         4    4
# 2020-10-05    6     6       6         6         6      6         6    6
# 2020-10-07    1     1       1         1         1      1         1    1
# 2020-10-08    6     6       6         6         6      6         6    6
# 2020-10-09    1     1       1         1         1      1         1    1
# 2020-10-10    4     4       4         4         4      4         4    4
# 2020-10-11    5     5       5         5         5      5         5    5
# 2020-10-12    5     5       5         5         5      5         5    5
# 2020-10-14    3     3       3         3         3      3         3    3
# 2020-10-15    1     1       1         1         1      1         1    1
# 2020-10-16    4     4       4         4         4      4         4    4
#
#                         firstm               lastm  ftol
# cdate
# 2020-10-03 2020-10-03 14:50:36 2020-10-03 21:05:18   6.0
# 2020-10-04 2020-10-04 07:47:14 2020-10-04 18:56:54  11.0
# 2020-10-05 2020-10-05 10:14:56 2020-10-05 20:20:10  10.0
# 2020-10-07 2020-10-07 18:04:50 2020-10-07 18:04:50   0.0
# 2020-10-08 2020-10-08 05:57:48 2020-10-08 19:14:22  13.0
# 2020-10-09 2020-10-09 13:45:28 2020-10-09 13:45:28   0.0
# 2020-10-10 2020-10-10 08:59:04 2020-10-10 19:34:22  10.0
# 2020-10-11 2020-10-11 07:17:54 2020-10-11 18:01:02  10.0
# 2020-10-12 2020-10-12 10:14:34 2020-10-12 18:43:28   8.0
# 2020-10-14 2020-10-14 08:26:40 2020-10-14 14:57:08   6.0
# 2020-10-15 2020-10-15 16:41:20 2020-10-15 16:41:20   0.0
# 2020-10-16 2020-10-16 10:23:46 2020-10-16 19:49:56   9.0

# %%
plt.bar(mgdf.index, mgdf.firstm.map(lambda x: 24*60), color='green')
plt.bar(mgdf.index, mgdf.lastm.map(dateless))
plt.plot(mgdf.index, mgdf.lastm.map(dateless), linestyle='none', marker='.')
plt.plot(mgdf.index, mgdf.firstm.map(dateless), linestyle='none', marker='.')
plt.bar(mgdf.index, mgdf.firstm.map(dateless), color='green')
end_plot()
plt.bar(mgdf.index, mgdf.cnt)
end_plot()
plt.bar(mgdf.index, mgdf.ftol)
end_plot()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# # Select days with enough data only

# %%
# Out:
#                      day  hour  minute  time_fmt time_str               ctime  \
# idx
# 2020-10-04 07:47:14    4     7      47       747     7:47 2020-10-04 07:47:14
# 2020-10-04 13:04:58    4    13       4      1304     13:4 2020-10-04 13:04:58
# 2020-10-04 14:45:54    4    14      45      1445    14:45 2020-10-04 14:45:54
# 2020-10-04 18:56:54    4    18      56      1856    18:56 2020-10-04 18:56:54
#
#                           cdate      filename    HD
# idx
# 2020-10-04 07:47:14  2020-10-04  IMG_0390.jpg  True
# 2020-10-04 13:04:58  2020-10-04  IMG_0391.jpg  True
# 2020-10-04 14:45:54  2020-10-04  IMG_0392.jpg  True
# 2020-10-04 18:56:54  2020-10-04  IMG_0396.jpg  True

# %%
# Out:
# [datetime.date(2020, 10, 4),
#  datetime.date(2020, 10, 5),
#  datetime.date(2020, 10, 8),
#  datetime.date(2020, 10, 10),
#  datetime.date(2020, 10, 11),
#  datetime.date(2020, 10, 12),
#  datetime.date(2020, 10, 16)]

# %%
high_days=list(mgdf[mgdf.cnt>=4].index)

# %%
# get meals in high days
meals['HD']=meals.index.map(lambda x: x.date() in high_days)
imeals = meals[meals.HD]

# %%
plt.hist(meals.hour, bins=10)
plt.hist(imeals.hour, bins=10)
end_plot()
# Out:
# No handles with labels found to put in legend.

# %%
imeals.ctime.max()
# Out:
# Timestamp('2020-10-16 19:49:56')

# %%
igday = imeals.groupby('cdate')
imgdf = igday.count()
imgdf['cnt']= mgdf.ctime
imgdf['firstm']=igday['ctime'].min()
imgdf['lastm']=igday['ctime'].max()
imgdf['ftol']=(imgdf['lastm']-imgdf['firstm']).astype('timedelta64[h]')
imgdf['ftol']
imgdf.ftol.hist()
end_plot()

imgdf.ftol.map(lambda x: 23-x).hist()
end_plot()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
plt.bar(imgdf.index, imgdf.firstm.map(lambda x: 24*60), color='green')
plt.bar(imgdf.index, imgdf.lastm.map(dateless))
plt.plot(imgdf.index, imgdf.lastm.map(dateless), linestyle='none', marker='.')
plt.plot(imgdf.index, imgdf.firstm.map(dateless), linestyle='none', marker='.')
plt.bar(imgdf.index, imgdf.firstm.map(dateless), color='green')
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# # Get glucose

# %%
# Out:
# array([datetime.date(2020, 10, 3), datetime.date(2020, 10, 3),
#        datetime.date(2020, 10, 3), ..., datetime.date(2020, 10, 14),
#        datetime.date(2020, 10, 15), datetime.date(2020, 10, 15)],
#       dtype=object)

# %%
glucose = pd.read_csv(PATH_GLUCOSE, skiprows=1)
glbl = 'Historic Glucose mmol/L'
tlbl = 'Device Timestamp'
t_ = 'dtime'
glucose['dtime']=pd.to_datetime(glucose[tlbl], format='%d-%m-%Y %H:%M')
glucose.set_index(t_, inplace=True)
glucose['t_']=glucose.index
glucose['date']=glucose.index.date
glucose['day']=glucose.index.day
glucose['dayofweek']=glucose.index.weekday
glucose['hour']=glucose.index.hour
glucose['minute']=glucose.index.minute
glucose['tminutes']=glucose.minute+60*glucose.hour
glucose['ftime']=glucose.minute+100*glucose.hour
glucose['strtime']=glucose.hour.map(lambda x: "{}:".format(x))+glucose.minute.astype(str)
glucose
glucose=glucose.loc["2020-05-16":]

# %% [markdown]
# # Analyze peaks

# %%
def get_integral(df, g_lbl):
    return sum((df.t_.diff() * df[g_lbl]).dropna())

# %%
def derive(recv):
    return recv.diff()/recv.index.to_series().diff().dt.total_seconds()

# %%
def time_diff(recv): 
    return recv.index.to_series().diff().dt.total_seconds()

# %%
dgdt=derive(glucose[glbl])
glucose['dg/dt']=dgdt

resize()
for i in [1, 10, 60]:
    dgdt.rolling(i).mean().plot(label=i)
end_plot()

# %%
GR = glucose.groupby(['date'])
max_deriv_day = GR['dg/dt'].max()
max_deriv_dayN =normalize(GR['dg/dt'].max())
mean_gl_day = GR[glbl].mean()
mean_gl_dayN = normalize(GR[glbl].mean())
resize(6,4)
plt.plot(max_deriv_day, mean_gl_day, linestyle='none', marker='.')
end_plot()

resize(6,4)
plt.plot(glucose['dg/dt'], glucose[glbl], linestyle='none', marker='.')
end_plot()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
# day var

resize(6,4)
dday=glucose.loc[high_days[0].strftime("%Y-%m-%d")]
plt.plot(dday['dg/dt'], dday[glbl])
dday=glucose.loc[high_days[-1].strftime("%Y-%m-%d")]
plt.plot(dday['dg/dt'], dday[glbl])
end_plot()
# Out:
# No handles with labels found to put in legend.

# %%
resize()
dd = glucose
sns.violinplot(dd[glbl],dd['dg/dt'])
plt.axhline(y=0)
end_plot()
resize()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### NOTE
# Insight: must keep glucose beyond 7.2 otherwise the derivative trends in the high range

# %%
day=high_days[0].strftime("%Y-%m-%d")
day1=high_days[1].strftime("%Y-%m-%d")

dday=glucose.loc[day]
dday1=glucose.loc[day1]
plt.plot(dday['tminutes'], dday[glbl].rolling(10).mean())
plt.plot(dday1['tminutes'], dday1[glbl].rolling(10).mean())

# %%
dglbl='dg/dt'

# %%
LIMIT = dday[dglbl].mean()+dday[dglbl].std()
LIMIT1 = dday1[dglbl].mean()+dday1[dglbl].std()

# %%
resize()

df=dday
plt.plot(df[glbl])
plt.plot(df[df[dglbl]>=LIMIT][glbl], linestyle='none', marker='*')
plt.plot(df[df[dglbl]<=0][glbl], linestyle='none', marker='*')

df=dday1
plt.plot(df[glbl])
plt.plot(df[df[dglbl]>=LIMIT1][glbl], linestyle='none', marker='*')
plt.plot(df[df[dglbl]<=0][glbl], linestyle='none', marker='*')

end_plot()

print("Peaks day 0, lim {} : {}".format(LIMIT, dday[dday[dglbl]>=LIMIT][glbl].count()))
print("Peaks day 1, lim {} : {}".format(LIMIT1, dday1[dday1[dglbl]>=LIMIT1][glbl].count()))
# Out:
# No handles with labels found to put in legend.
# Peaks day 0, lim 0.00040978250887449606 : 6
# Peaks day 1, lim 0.0003343065536191762 : 9

# %% [markdown]
# **day 1 seems better**

# %%
meals[day]
# Out:
#                      day  hour  minute  time_fmt time_str               ctime  \
# idx
# 2020-10-04 07:47:14    4     7      47       747     7:47 2020-10-04 07:47:14
# 2020-10-04 13:04:58    4    13       4      1304     13:4 2020-10-04 13:04:58
# 2020-10-04 14:45:54    4    14      45      1445    14:45 2020-10-04 14:45:54
# 2020-10-04 18:56:54    4    18      56      1856    18:56 2020-10-04 18:56:54
#
#                           cdate      filename    HD
# idx
# 2020-10-04 07:47:14  2020-10-04  IMG_0390.jpg  True
# 2020-10-04 13:04:58  2020-10-04  IMG_0391.jpg  True
# 2020-10-04 14:45:54  2020-10-04  IMG_0392.jpg  True
# 2020-10-04 18:56:54  2020-10-04  IMG_0396.jpg  True

# %%
meals[day1]
# Out:
#                      day  hour  minute  time_fmt time_str               ctime  \
# idx
# 2020-10-05 10:14:56    5    10      14      1014    10:14 2020-10-05 10:14:56
# 2020-10-05 17:06:26    5    17       6      1706     17:6 2020-10-05 17:06:26
# 2020-10-05 17:49:58    5    17      49      1749    17:49 2020-10-05 17:49:58
# 2020-10-05 19:51:54    5    19      51      1951    19:51 2020-10-05 19:51:54
# 2020-10-05 20:19:44    5    20      19      2019    20:19 2020-10-05 20:19:44
# 2020-10-05 20:20:10    5    20      20      2020    20:20 2020-10-05 20:20:10
#
#                           cdate      filename    HD
# idx
# 2020-10-05 10:14:56  2020-10-05  IMG_0401.jpg  True
# 2020-10-05 17:06:26  2020-10-05  IMG_0404.jpg  True
# 2020-10-05 17:49:58  2020-10-05  IMG_0406.jpg  True
# 2020-10-05 19:51:54  2020-10-05  IMG_0409.jpg  True
# 2020-10-05 20:19:44  2020-10-05  IMG_0412.jpg  True
# 2020-10-05 20:20:10  2020-10-05  IMG_0413.jpg  True
